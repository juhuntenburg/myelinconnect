# %%
from IPython.display import Image

# %%
raw_clust='/scr/ilz3/myelinconnect/pics/raw_clust/rh_3_%s_%s.png'
thr_clust='/scr/ilz3/myelinconnect/pics/sub_thr_clust/rh_3_%s_%s.png'

# %%
k='7'
view='lat'

# %%
Image(filename=raw_clust%(k,view))

# %%
Image(filename=thr_clust%(k,view))
