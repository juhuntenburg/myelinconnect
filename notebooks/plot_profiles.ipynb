# %%
# %matplotlib inline

# %%
from __future__ import division
import numpy as np
from vtk_rw import read_vtk, write_vtk
import pandas as pd
import matplotlib.pyplot as plt

# %%
sub = 'KSYT'
hemi = 'rh'

# %%
pro_file = '/scr/ilz3/myelinconnect/all_data_on_simple_surf/t1/%s_%s_profiles_lowres.npy'%(sub, hemi)

# %%
profiles = np.load(pro_file)

# %%
profiles.shape
# Out:
# (75589, 11)

# %%
v = 7050

# 1000 !

# %%
fig = plt.figure(figsize=(10,10))
fig.add_subplot(221)
plt.plot(profiles[v])
plt.title('full')
fig.add_subplot(222)
plt.plot(profiles[v][3:8])
plt.title('excl 3')
fig.add_subplot(223)
plt.plot(profiles[v][2:9])
plt.title('excl 2')
fig.add_subplot(224)
plt.plot(profiles[v][1:10])
plt.title('excl 1')

# %%
mean3_7= np.mean(profiles[:,3:8], axis=1)

# %%
mean3_7.shape
# Out:
# (75589,)

# %%
test_mean = 0
for i in range(len(profiles[v])):
    if i in [3,4,5,6,7]:
        test_mean += profiles[v][i]
test_mean / 5
# Out:
# 2414.0967285156248

# %%
mean3_7[v]
# Out:
# 2414.0967285156248

# %%
profiles.T.shape
# Out:
# (11, 75589)

# %%
for p in range(profiles.shape[1]):
    print profiles[:,p, np.newaxis].shape
# Out:
# (75589, 1)
# (75589, 1)
# (75589, 1)
# (75589, 1)
# (75589, 1)
# (75589, 1)
# (75589, 1)
# (75589, 1)
# (75589, 1)
# (75589, 1)
# (75589, 1)

# %%
profiles.shape
# Out:
# (75589, 11)

# %%
v,f,d=read_vtk('/scr/ilz3/myelinconnect/all_data_on_simple_surf/surfs/lowres_%s_d.vtk'%('rh'))

# %%
v.shape
# Out:
# (75589, 3)

# %%
f.shape
# Out:
# (151082, 3)
